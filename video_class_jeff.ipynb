# %%
import os
import cv2

import numpy as np
import matplotlib.pyplot as plt

from fastai.vision import *
from fastai import *

# %%
class Video:
    
    from google.colab import drive
    drive.mount('/content/gdrive', force_remount=True)

    def __init__(self):
        self.data = None
        self.learn = None
        self.learners = {} # store name:learn,data

        
    def video_to_frames(self,filepath,vid_fname,dest,verbose=False):
        '''
        convert mp4 video file to jpg frames
        filepath    : path cwd, str
        vid_fname   : filename of mp4 to process, str
        dest        : destination folder to create, str
        verbose     : whether to print processing status, bool 
        '''
        import cv2
        import numpy as np
        import os
        print(filepath+vid_fname)
        # Playing video from file:
        cap = cv2.VideoCapture(filepath+vid_fname)
        
        try:
            path = filepath+dest
            if not os.path.exists(path):
                print('adding:\n'.format(path))
                os.mkdir(path)
        except OSError:
            print ('Error: Creating directory of data')

        # get total frames in cv2 object
        n_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        print('total frames:',n_frames)
        currentFrame = 0
        for i in range(n_frames):     
            # Capture frame-by-frame
            ret, frame = cap.read()

            # Saves image of the current frame in jpg file
            name = path+'/frame' + str(currentFrame) + '.jpg'
            if verbose:
                print ('Creating...' + name)
            cv2.imwrite(name, frame)

            # To stop duplicate images
            currentFrame += 1

        # When everything done, release the capture
        cap.release()
        cv2.destroyAllWindows()
        print('\n{} converted to .jpg frames in:\n{}'.format(vid_fname,filepath+dest))
        

    def pil_image(self,path,folder,fname):
        '''
        opens jpg from path+folder+fname as pil image
        path    : dir path, str
        folder  : name of folder with jpgs, str
        fname   : name of jpg file, str
        returns : jpg 
        '''
        return Image.open(path+folder+'/'+fname)

    
    def image_array(self,path,folder,fname):
        '''
        opens jpg from path+folder+fname as np.array
        path    : dir path, str
        folder  : name of folder with jpgs, str
        fname   : name of jpg file, str
        returns : jpg image as np.array
        '''
        return np.asarray(Image.open(path+folder+'/'+fname))
    
    

    def frames_to_video(self,path,frames_folder,fname_out,
                        pred_dict,
                        fontsz=1,coord=(40,75),color=(255,255,255),thickness=2,
                        threshold=.9,fps=10):
        '''
        converts jpg frames to avi video
        # https://medium.com/@iKhushPatel/convert-video-to-images-images-to-video-using-opencv-python-db27a128a481
        path          : full path to cwd, str
        frames_folder : name of folder where jpg frames are stored, str
        fname_out     : file name of output .avi video, str
        pred_dict     : hash of cnn_name: pretrained cnn_leaner,ImageDataBunch
        fontsz        : font size of text overlay, float
        coord         : loc of text overlay, tuple of int
        color         : rgb color, tuple of int
        thickness     : font boldness, int
        threshold     : prediction proba threshold to overlay text, float
        returns       : None
        '''

        from os.path import isfile, join

        root,dirs,files = next(os.walk(path+frames_folder))
        print('Reading .jpg frames in:\n{}'.format(path+frames_folder))

        pathIn= path+frames_folder 
        pathOut = path+fname_out
        fps = fps
        frame_array = []
        file_name_list = [root+'/'+files[i] for i in range(len(files))]
        # must sort else video is reversed
        for i in range(len(file_name_list)):
            img = cv2.imread(file_name_list[i]) # img .jpg
            im_arr = np.asarray(img) # convert to np array for overlay_text 
            # add prediction text annotation
            pred_tensor = pred_dict[files[i]][1]
            cnn_name = pred_dict[files[i]][0]
            data_bunch = self.learners[cnn_name].data 
            class_pred, pred_proba = self.get_prediction(pred_tensor,
                                                         data_bunch.classes)
            # text string to overlay 
            if pred_proba >= threshold:
                s='{} {:.3f}'.format(class_pred,pred_proba).upper()
            else:
                s = '.'
            
            img = self.overlay_text(im_arr,s,coord=coord,
                     font=cv2.FONT_HERSHEY_SIMPLEX,
                     fontsz=fontsz,color=color,thickness=thickness)        
            height, width, layers = img.shape
            size = (width,height)

            #insert frame into an image array
            frame_array.append(img)
            
        out = cv2.VideoWriter(pathOut,cv2.VideoWriter_fourcc(*'DIVX'), fps, size)
        for i in range(len(frame_array)):
            # writing to a image array
            out.write(frame_array[i])
        out.release()
        print('\n.jpg frames to .avi video conversion complete')

        
    def store_predictions(self,file_path):
        '''
        make predictions on jpg frames in file_path+frame_folder
        and save the predictions in a dictionary along with the jpg image
        file_path    : base_dir, str
        returns      : OrderedDict fname str as key: list [tensor,jpg img] as value
        '''
        print('\ncomputing predictions in:\n{}'.format(file_path))
        root,dirs,files = next(os.walk(file_path))
        # populate row,col size counter dict
        from collections import OrderedDict
        d = OrderedDict()
        for i in range(len(files)):
            img_pth = root+'/'+files[i] 
            # fastai open_image for compatible image object in predict method
            img = open_image(img_pth)
            pred_max = -1
            best_torch_pred = None
            best_classes = []
            best_learn_key = None
            # obtain predictions for each learner
            for learn_key in self.learners:
                learn = self.learners[learn_key]
                data = learn.data
                curr_torch_pred = learn.predict(img)
                
                # determine which learner has strongest prediction proba  
                curr_proba = self.get_prediction(curr_torch_pred,data.classes)[1] 
                if curr_proba > pred_max:
                    # assign prediction and corresponding attributes
                    pred_max = curr_proba
                    best_torch_pred = curr_torch_pred
                    best_classes = data.classes
                    best_learn_key = learn_key
            d[files[i]] = [best_learn_key,best_torch_pred,best_classes]
        return d 
    
    def get_prediction(self,torch_pred,classes):
        '''
        obtains class pred from trained cnn_learner pytorch tensor output
        torch_pred   : prediction probas, pytorch tensor
        classes      : classes in fastai data obj .classes, list
        returns      : tuple of (class,proba) 
        '''
        predlist = (torch_pred[2]).tolist()
        pred_ix = np.argmax(predlist)
        return classes[pred_ix],predlist[pred_ix]

    def overlay_text(self,img_arr,text_str,coord=(50,75),
                     font=cv2.FONT_HERSHEY_SIMPLEX,
                     fontsz=2,color=(240,240,0),thickness=2):
        '''
        overlay text to an image array
        img_arr    : image, np.array
        text_str   : value to write, str
        coord      : loc of text, tuple of int
        font       : cv2 specified font
        fontsz     : fontScale of text, int
        color      : rgb tuple of 3 ints
        thickness  : thickness of font, int
        returns    : image, jpg
        '''
        img = cv2.putText(img_arr,text_str,coord,font,fontsz,color,thickness)
        return img


root_dir = "/content/gdrive/My Drive/"
dir = 'fellowshipai-data/jeffrey/video_challenge/'
base_dir = root_dir + dir


v = Video()
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ### Load Pretrained `cnn_learner`s
# - doneness and raw foods models
# - raw group's model requires OverSamplingCallback
# - store dict of `cnn_learner pkl` filename as key : pretrained `cnn_learner` object as values

# %%
from torch.utils.data.sampler import WeightedRandomSampler

__all__ = ['OverSamplingCallback']

class OverSamplingCallback(LearnerCallback):
    def __init__(self,learn:Learner,weights:torch.Tensor=None):
        super().__init__(learn)
        self.weights = weights
    def on_train_begin(self, **kwargs):
        self.labels = self.learn.data.train_dl.dataset.y.items
        _, counts = np.unique(self.labels,return_counts=True)
        if self.weights is None: self.weights = torch.DoubleTensor((1/counts)[self.labels]) 
        self.label_counts = np.bincount([self.learn.data.train_dl.dataset.y[i].data for i in range(len(self.learn.data.train_dl.dataset))])
        self.total_len_oversample = int(self.learn.data.c*np.max(self.label_counts))
        self.learn.data.train_dl.dl.batch_sampler = BatchSampler(WeightedRandomSampler(self.weights,self.total_len_oversample), self.learn.data.train_dl.batch_size,False)



# path = 'fellowshipai-data/final_3_class_data_train_test_split/'
# path = 'fellowshipai-data/data_backup/'

path = 'fellowshipai-data/jeffrey/video_challenge/models'
model_path = root_dir+path

saved_models = ['rn34_base_jeff.pkl','nyc_raw_food.pkl']


v.learners = {model_name:load_learner(model_path,model_name) for model_name in saved_models}

# %% [markdown]
# ### Transform .mp4 video to .jpg
# `video_to_frames` method processes an `.mp4` in Google Drive cwd and makes a new folder to store `jpg` files as output

# %%
# v.video_to_frames(base_dir,'Chicken - 11679.mp4','chicken_11679',verbose=False)
# v.video_to_frames(base_dir,'SteakAvo.mp4','steak_avo',verbose=False)
v.video_to_frames(base_dir,'SteakAvo.mp4','steak_avo',verbose=False)
# Out:
# /content/gdrive/My Drive/fellowshipai-data/jeffrey/video_challenge/SteakAvo.mp4
# total frames: 1209
#
# SteakAvo.mp4 converted to .jpg frames in:
# /content/gdrive/My Drive/fellowshipai-data/jeffrey/video_challenge/steak_avo

# %% [markdown]
# ### Predict Class on `jpg` frames Data and Store Pytorch prediction tensors and images in OrderedDict
#
# - OrderedDict key is filename of `jpg` frame
# - OrderedDict value is list of pretrained `cnn_learner` `.pkl` filename, Pytorch prediction tensor, list of corresonding class labels for the learner.

# %%
# frames_file_path = base_dir+'chicken_11679'
frames_file_path = base_dir+'steak_avo'


# chicken_pred_dict = v.store_predictions(frames_file_path)
# chicken_pred_dict

steak_avo_pred_dict = v.store_predictions(frames_file_path)
steak_avo_pred_dict
# Out:
# computing predictions in:
# /content/gdrive/My Drive/fellowshipai-data/jeffrey/video_challenge/steak_avo
# OrderedDict([('frame0.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.5480, 0.0212, 0.4307])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame1.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.5514, 0.0212, 0.4274])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame2.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw,
#                 tensor(2),
#                 tensor([7.6469e-04, 1.0830e-04, 9.9913e-01])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame3.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw,
#                 tensor(2),
#                 tensor([7.2589e-04, 1.3524e-04, 9.9914e-01])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame4.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw,
#                 tensor(2),
#                 tensor([5.9299e-05, 2.2518e-05, 9.9992e-01])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame5.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw,
#                 tensor(2),
#                 tensor([5.5797e-06, 2.0287e-06, 9.9999e-01])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame6.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw,
#                 tensor(2),
#                 tensor([4.8184e-08, 5.0758e-09, 1.0000e+00])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame7.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw,
#                 tensor(2),
#                 tensor([2.0137e-08, 2.1760e-09, 1.0000e+00])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame8.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw,
#                 tensor(2),
#                 tensor([6.8058e-08, 2.9672e-09, 1.0000e+00])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame9.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw,
#                 tensor(2),
#                 tensor([1.2037e-07, 3.7445e-09, 1.0000e+00])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame10.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw,
#                 tensor(2),
#                 tensor([2.0889e-08, 6.1919e-10, 1.0000e+00])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame11.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw,
#                 tensor(2),
#                 tensor([5.6732e-07, 1.6478e-08, 1.0000e+00])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame12.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw,
#                 tensor(2),
#                 tensor([2.4677e-06, 7.2439e-08, 1.0000e+00])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame13.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw,
#                 tensor(2),
#                 tensor([3.7943e-05, 2.7302e-06, 9.9996e-01])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame14.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw,
#                 tensor(2),
#                 tensor([1.0448e-06, 5.3782e-08, 1.0000e+00])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame15.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw,
#                 tensor(2),
#                 tensor([1.7245e-07, 1.0072e-08, 1.0000e+00])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame16.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw,
#                 tensor(2),
#                 tensor([3.9710e-07, 1.9401e-08, 1.0000e+00])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame17.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw,
#                 tensor(2),
#                 tensor([2.8486e-07, 1.6655e-08, 1.0000e+00])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame18.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw,
#                 tensor(2),
#                 tensor([4.0955e-07, 2.0868e-08, 1.0000e+00])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame19.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw,
#                 tensor(2),
#                 tensor([2.1843e-07, 1.2250e-08, 1.0000e+00])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame20.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw,
#                 tensor(2),
#                 tensor([1.3771e-07, 6.8433e-09, 1.0000e+00])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame21.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw,
#                 tensor(2),
#                 tensor([2.2879e-08, 8.6302e-10, 1.0000e+00])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame22.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw,
#                 tensor(2),
#                 tensor([5.2831e-09, 1.2839e-10, 1.0000e+00])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame23.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw,
#                 tensor(2),
#                 tensor([1.2087e-08, 5.4440e-10, 1.0000e+00])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame24.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw,
#                 tensor(2),
#                 tensor
jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked,
#                 tensor(0),
#                 tensor([9.6443e-01, 6.4307e-04, 3.4931e-02])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame982.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked,
#                 tensor(0),
#                 tensor([9.8529e-01, 2.2061e-04, 1.4492e-02])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame983.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked,
#                 tensor(0),
#                 tensor([9.8634e-01, 2.0668e-04, 1.3453e-02])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame984.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked,
#                 tensor(0),
#                 tensor([9.8128e-01, 2.2271e-04, 1.8499e-02])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame985.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked,
#                 tensor(0),
#                 tensor([9.7320e-01, 2.5129e-04, 2.6544e-02])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame986.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked,
#                 tensor(0),
#                 tensor([9.2158e-01, 4.7786e-04, 7.7944e-02])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame987.jpg',
#               ['nyc_raw_food.pkl',
#                (Category rabbit,
#                 tensor(20),
#                 tensor([1.2865e-03, 4.1561e-04, 8.3823e-04, 9.2365e-05, 3.1247e-04, 4.4351e-04,
#                         2.2018e-04, 5.0639e-05, 4.6975e-03, 6.0944e-05, 1.1529e-03, 2.2314e-04,
#                         4.2323e-03, 1.9017e-04, 3.1302e-04, 2.4447e-04, 7.2196e-05, 1.4635e-03,
#                         2.5282e-03, 3.4412e-04, 9.5276e-01, 2.5102e-05, 6.6346e-03, 1.5033e-03,
#                         6.2956e-03, 1.3951e-04, 1.3284e-02, 1.7555e-04])),
#                ['asparagus',
#                 'bagels',
#                 'broccoli',
#                 'cake',
#                 'carrots',
#                 'casserole',
#                 'cauliflower',
#                 'chicken_breast',
#                 'cookie',
#                 'croissant',
#                 'dorado',
#                 'eggplant',
#                 'kebab',
#                 'muffin',
#                 'mushrooms',
#                 'nuts',
#                 'pepper',
#                 'pizza',
#                 'pork',
#                 'potatoes',
#                 'rabbit',
#                 'ratatouille',
#                 'ribs',
#                 'salmon',
#                 'steak',
#                 'tilapia',
#                 'tuna_steak',
#                 'whole_chicken']]),
#              ('frame988.jpg',
#               ['nyc_raw_food.pkl',
#                (Category rabbit,
#                 tensor(20),
#                 tensor([5.9499e-04, 3.8422e-04, 3.3563e-04, 9.3919e-05, 2.1779e-04, 1.9408e-04,
#                         5.2355e-05, 8.0825e-05, 3.9244e-03, 4.7670e-05, 4.3574e-04, 1.0421e-04,
#                         1.9466e-03, 1.5135e-04, 2.1348e-04, 1.0664e-04, 4.8367e-05, 1.1712e-03,
#                         1.1322e-03, 4.0861e-04, 9.6793e-01, 1.6916e-05, 2.2262e-03, 5.4354e-04,
#                         4.2551e-03, 1.7496e-04, 1.3119e-02, 9.4821e-05])),
#                ['asparagus',
#                 'bagels',
#                 'broccoli',
#                 'cake',
#                 'carrots',
#                 'casserole',
#                 'cauliflower',
#                 'chicken_breast',
#                 'cookie',
#                 'croissant',
#                 'dorado',
#                 'eggplant',
#                 'kebab',
#                 'muffin',
#                 'mushrooms',
#                 'nuts',
#                 'pepper',
#                 'pizza',
#                 'pork',
#                 'potatoes',
#                 'rabbit',
#                 'ratatouille',
#                 'ribs',
#                 'salmon',
#                 'steak',
#                 'tilapia',
#                 'tuna_steak',
#                 'whole_chicken']]),
#              ('frame989.jpg',
#               ['nyc_raw_food.pkl',
#                (Category rabbit,
#                 tensor(20),
#                 tensor([1.0443e-03, 1.0658e-03, 4.2129e-04, 1.1188e-04, 2.0579e-04, 3.5630e-04,
#                         1.1371e-04, 1.4567e-04, 6.7926e-03, 1.0239e-04, 3.9619e-04, 8.3122e-05,
#                         3.1381e-03, 3.7309e-04, 4.8859e-04, 2.1710e-04, 1.3442e-04, 2.0856e-03,
#                         1.9689e-03, 4.8585e-04, 9.6007e-01, 3.0653e-05, 8.2043e-03, 3.5227e-04,
#                         4.3925e-03, 1.5616e-04, 6.8988e-03, 1.6170e-04])),
#                ['asparagus',
#                 'bagels',
#                 'broccoli',
#                 'cake',
#                 'carrots',
#                 'casserole',
#                 'cauliflower',
#                 'chicken_breast',
#                 'cookie',
#                 'croissant',
#                 'dorado',
#                 'eggplant',
#                 'kebab',
#                 'muffin',
#                 'mushrooms',
#                 'nuts',
#                 'pepper',
#                 'pizza',
#                 'pork',
#                 'potatoes',
#                 'rabbit',
#                 'ratatouille',
#                 'ribs',
#                 'salmon',
#                 'steak',
#                 'tilapia',
#                 'tuna_steak',
#                 'whole_chicken']]),
#              ('frame990.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked,
#                 tensor(0),
#                 tensor([9.8656e-01, 3.0379e-04, 1.3137e-02])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame991.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.9567, 0.0011, 0.0422])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame992.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked,
#                 tensor(0),
#                 tensor([9.2357e-01, 4.3739e-04, 7.5988e-02])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame993.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked,
#                 tensor(0),
#                 tensor([9.8693e-01, 2.5390e-04, 1.2818e-02])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame994.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.8448, 0.0012, 0.1540])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame995.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked,
#                 tensor(0),
#                 tensor([9.8224e-01, 6.5218e-04, 1.7106e-02])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame996.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.5519, 0.0012, 0.4470])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame997.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.5911, 0.0006, 0.4083])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame998.jpg',
#               ['nyc_raw_food.pkl',
#                (Category kebab,
#                 tensor(12),
#                 tensor([3.7663e-03, 8.7547e-04, 2.8485e-03, 1.0280e-03, 1.2225e-03, 7.7168e-04,
#                         1.0961e-03, 1.5042e-03, 4.0361e-02, 8.1955e-04, 8.6961e-03, 1.8841e-03,
#                         7.0176e-01, 1.1232e-03, 4.7706e-03, 3.5168e-04, 5.1881e-03, 5.5942e-02,
#                         8.4652e-04, 5.7956e-03, 7.9695e-02, 7.0232e-04, 2.3536e-03, 3.0444e-03,
#                         4.2450e-03, 8.7183e-04, 6.7655e-02, 7.7955e-04])),
#                ['asparagus',
#                 'bagels',
#                 'broccoli',
#                 'cake',
#                 'carrots',
#                 'casserole',
#                 'cauliflower',
#                 'chicken_breast',
#                 'cookie',
#                 'croissant',
#                 'dorado',
#                 'eggplant',
#                 'kebab',
#                 'muffin',
#                 'mushrooms',
#                 'nuts',
#                 'pepper',
#                 'pizza',
#                 'pork',
#                 'potatoes',
#                 'rabbit',
#                 'ratatouille',
#                 'ribs',
#                 'salmon',
#                 'steak',
#                 'tilapia',
#                 'tuna_steak',
#                 'whole_chicken']]),
#              ('frame999.jpg',
#               ['nyc_raw_food.pkl',
#                (Category kebab,
#                 tensor(12),
#                 tensor([8.9180e-04, 2.4201e-03, 1.9117e-03, 1.2976e-03, 7.3429e-04, 7.2122e-04,
#                         7.6865e-04, 1.5553e-03, 5.9801e-02, 1.4054e-03, 1.1617e-02, 9.0346e-04,
#                         7.6524e-01, 1.1695e-03, 6.6465e-03, 2.5932e-04, 7.8758e-03, 6.7276e-02,
#                         3.7892e-04, 4.1455e-03, 2.5649e-02, 1.8841e-03, 7.4295e-04, 1.3810e-03,
#                         1.3709e-03, 6.8193e-04, 2.8709e-02, 2.5564e-03])),
#                ['asparagus',
#                 'bagels',
#                 'broccoli',
#                 'cake',
#                 'carrots',
#                 'casserole',
#                 'cauliflower',
#                 'chicken_breast',
#                 'cookie',
#                 'croissant',
#                 'dorado',
#                 'eggplant',
#                 'kebab',
#                 'muffin',
#                 'mushrooms',
#                 'nuts',
#                 'pepper',
#                 'pizza',
#                 'pork',
#                 'potatoes',
#                 'rabbit',
#                 'ratatouille',
#                 'ribs',
#                 'salmon',
#                 'steak',
#                 'tilapia',
#                 'tuna_steak',
#                 'whole_chicken']]),
#              ...])

# %% [markdown]
# ### Overlay `cnn_leaner` Class Prediction Annotations and Convert `.jpg` Frames back to `.avi` Video
#
# - The method `frames_to_video` loops over each group's pretrained models and selects the class for a given `jpg` frame which has the maximum probability among all proabilities in pytorch prediction tensor.
#
# - The method writes to the `jpg` the predicted class and the corresponding class probability.
#
# - Finally, the method saves converts frames

# %%
video_names = [('steak_avo','steak_avo.avi',steak_avo_pred_dict)]

for tup in video_names:
    v.frames_to_video(base_dir,tup[0],tup[1],
                      tup[2],
                      coord=(70,50),fontsz=.6,color=(250,250,250),thickness=2,
                      threshold=.925,fps=5)
# Out:
# Reading .jpg frames in:
# /content/gdrive/My Drive/fellowshipai-data/jeffrey/video_challenge/steak_avo
#
# .jpg frames to .avi video conversion complete

# %%
chicken_pred_dict
# Out:
# OrderedDict([('frame0.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.5170, 0.0078, 0.4752])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame1.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw, tensor(2), tensor([0.4521, 0.0068, 0.5411])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame2.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.5101, 0.0077, 0.4822])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame3.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw, tensor(2), tensor([0.4770, 0.0066, 0.5163])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame4.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.5012, 0.0075, 0.4913])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame5.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw, tensor(2), tensor([0.4644, 0.0069, 0.5287])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame6.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw, tensor(2), tensor([0.3695, 0.0057, 0.6248])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame7.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw, tensor(2), tensor([0.2413, 0.0037, 0.7550])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame8.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw, tensor(2), tensor([0.2822, 0.0055, 0.7123])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame9.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw, tensor(2), tensor([0.2924, 0.0052, 0.7024])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame10.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw, tensor(2), tensor([0.4023, 0.0060, 0.5918])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame11.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw, tensor(2), tensor([0.3882, 0.0055, 0.6063])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame12.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw, tensor(2), tensor([0.3509, 0.0047, 0.6444])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame13.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw, tensor(2), tensor([0.3166, 0.0053, 0.6781])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame14.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw, tensor(2), tensor([0.2375, 0.0047, 0.7578])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame15.jpg',
#               ['nyc_raw_food.pkl',
#                (Category pepper,
#                 tensor(16),
#                 tensor([8.1847e-04, 8.9205e-03, 3.0734e-03, 1.0769e-02, 6.3538e-03, 1.2114e-03,
#                         9.4586e-02, 3.4867e-03, 2.1654e-03, 1.0208e-02, 8.7489e-04, 1.2411e-02,
#                         1.3161e-01, 6.0220e-03, 2.4686e-03, 1.0531e-03, 5.6190e-01, 6.6050e-03,
#                         3.2422e-02, 5.3456e-04, 4.6340e-02, 2.9965e-02, 4.7148e-03, 1.1156e-02,
#                         1.9542e-03, 2.7953e-03, 2.4482e-03, 3.1397e-03])),
#                ['asparagus',
#                 'bagels',
#                 'broccoli',
#                 'cake',
#                 'carrots',
#                 'casserole',
#                 'cauliflower',
#                 'chicken_breast',
#                 'cookie',
#                 'croissant',
#                 'dorado',
#                 'eggplant',
#                 'kebab',
#                 'muffin',
#                 'mushrooms',
#                 'nuts',
#                 'pepper',
#                 'pizza',
#                 'pork',
#                 'potatoes',
#                 'rabbit',
#                 'ratatouille',
#                 'ribs',
#                 'salmon',
#                 'steak',
#                 'tilapia',
#                 'tuna_steak',
#                 'whole_chicken']]),
#              ('frame16.jpg',
#               ['nyc_raw_food.pkl',
#                (Category pepper,
#                 tensor(16),
#                 tensor([7.9734e-04, 7.4881e-03, 3.2790e-03, 1.1510e-02, 5.5815e-03, 1.1233e-03,
#                         9.3764e-02, 3.1443e-03, 2.1448e-03, 8.8978e-03, 1.0099e-03, 1.2067e-02,
#                         1.4283e-01, 7.1840e-03, 2.1366e-03, 1.0951e-03, 5.4893e-01, 6.5951e-03,
#                         2.9779e-02, 4.4854e-04, 5.3456e-02, 3.0168e-02, 4.4373e-03, 1.1614e-02,
#                         1.7408e-03, 2.9663e-03, 2.2926e-03, 3.5219e-03])),
#                ['asparagus',
#                 'bagels',
#                 'broccoli',
#                 'cake',
#                 'carrots',
#                 'casserole',
#                 'cauliflower',
#                 'chicken_breast',
#                 'cookie',
#                 'croissant',
#                 'dorado',
#                 'eggplant',
#                 'kebab',
#                 'muffin',
#                 'mushrooms',
#                 'nuts',
#                 'pepper',
#                 'pizza',
#                 'pork',
#                 'potatoes',
#                 'rabbit',
#                 'ratatouille',
#                 'ribs',
#                 'salmon',
#                 'steak',
#                 'tilapia',
#                 'tuna_steak',
#                 'whole_chicken']]),
#              ('frame17.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw, tensor(2), tensor([0.3426, 0.0077, 0.6497])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame18.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw, tensor(2), tensor([0.3501, 0.0079, 0.6420])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame19.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw, tensor(2), tensor([0.2835, 0.0057, 0.7107])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame20.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw, tensor(2), tensor([0.3444, 0.0061, 0.6496])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame21.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw, tensor(2), tensor([0.3111, 0.0071, 0.6819])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame22.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw, tensor(2), tensor([0.2805, 0.0065, 0.7129])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame23.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw, tensor(2), tensor([0.2400, 0.0063, 0.7537])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame24.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw, tensor(2), tensor([0.3519, 0.0100, 0.6381])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame25.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw, tensor(2), tensor([0.3208, 0.0097, 0.6694])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame26.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw, tensor(2), tensor([0.3293, 0.0086, 0.6621])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame27.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw, tensor(2), tensor([0.3990, 0.0116, 0.5894])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame28.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw, tensor(2), tensor([0.3813, 0.0100, 0.6088])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame29.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw, tensor(2), tensor([0.2928, 0.0065, 0.7007])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame30.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw, tensor(2), tensor([0.3302, 0.0058, 0.6640])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame31.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw, tensor(2), tensor([0.2720, 0.0048, 0.7233])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame32.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw, tensor(2), tensor([0.3278, 0.0051, 0.6671])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame33.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw, tensor(2), tensor([0.3721, 0.0073, 0.6206])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame34.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw, tensor(2), tensor([0.4592, 0.0080, 0.5329])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame35.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw, tensor(2), tensor([0.4607, 0.0076, 0.5317])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame36.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.5133, 0.0067, 0.4799])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame37.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw, tensor(2), tensor([0.4708, 0.0062, 0.5231])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame38.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.5625, 0.0059, 0.4315])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame39.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.6688, 0.0050, 0.3262])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame40.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.6722, 0.0060, 0.3219])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame41.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.7696, 0.0065, 0.2239])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame42.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.7789, 0.0083, 0.2128])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame43.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.8528, 0.0081, 0.1391])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame44.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.8656, 0.0067, 0.1277])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame45.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.8555, 0.0074, 0.1371])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame46.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.8056, 0.0066, 0.1879])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame47.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.7941, 0.0086, 0.1973])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame48.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.8071, 0.0083, 0.1846])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame49.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.7455, 0.0061, 0.2484])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame50.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.6328, 0.0067, 0.3605])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame51.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.7751, 0.0060, 0.2189])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame52.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.8368, 0.0057, 0.1575])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame53.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.7483, 0.0072, 0.2444])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame54.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.7317, 0.0074, 0.2609])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame55.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.7962, 0.0064, 0.1974])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame56.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.8390, 0.0062, 0.1548])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame57.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.8436, 0.0068, 0.1496])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame58.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.8536, 0.0077, 0.1387])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame59.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.8699, 0.0063, 0.1238])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame60.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.8653, 0.0064, 0.1283])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame61.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.7731, 0.0072, 0.2197])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame62.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.7608, 0.0062, 0.2329])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame63.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.7593, 0.0046, 0.2360])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame64.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.7561, 0.0047, 0.2391])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame65.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.7779, 0.0049, 0.2172])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame66.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.7139, 0.0043, 0.2818])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame67.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.7016, 0.0045, 0.2938])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame68.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.8126, 0.0034, 0.1840])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame69.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.8150, 0.0027, 0.1823])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame70.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.7495, 0.0030, 0.2475])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame71.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.7937, 0.0033, 0.2030])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame72.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.8191, 0.0029, 0.1780])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame73.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.6955, 0.0030, 0.3014])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame74.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.6211, 0.0025, 0.3764])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame75.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.5753, 0.0023, 0.4224])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame76.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.5682, 0.0021, 0.4297])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame77.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw, tensor(2), tensor([0.3646, 0.0021, 0.6333])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame78.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.6343, 0.0023, 0.3634])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame79.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.5594, 0.0024, 0.4382])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame80.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.6531, 0.0025, 0.3444])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame81.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category raw, tensor(2), tensor([0.4735, 0.0022, 0.5244])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame82.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.6863, 0.0028, 0.3109])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame83.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.5860, 0.0026, 0.4113])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame84.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.6964, 0.0034, 0.3002])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame85.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.7420, 0.0034, 0.2546])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame86.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.7581, 0.0026, 0.2394])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame87.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.7377, 0.0022, 0.2600])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame88.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.7751, 0.0026, 0.2223])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame89.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.8953, 0.0021, 0.1026])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame90.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.9264, 0.0019, 0.0717])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame91.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.9016, 0.0019, 0.0965])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame92.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.8564, 0.0014, 0.1422])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame93.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.8373, 0.0012, 0.1615])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame94.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.8579, 0.0012, 0.1409])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame95.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.6299, 0.0010, 0.3690])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame96.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.7663, 0.0011, 0.2326])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame97.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.7967, 0.0009, 0.2024])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame98.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.7381, 0.0011, 0.2608])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame99.jpg',
#               ['nyc_raw_food.pkl',
#                (Category kebab,
#                 tensor(12),
#                 tensor([2.7070e-04, 2.1136e-03, 1.9085e-03, 1.8430e-03, 7.2412e-03, 2.7418e-03,
#                         8.3848e-02, 1.8466e-03, 1.1673e-03, 2.1148e-02, 1.7638e-03, 2.5607e-03,
#                         7.0698e-01, 1.4933e-02, 8.0486e-04, 3.8476e-04, 4.1744e-02, 4.1659e-03,
#                         2.5255e-02, 1.3843e-04, 4.3591e-02, 6.5581e-03, 4.0597e-03, 1.4166e-02,
#                         1.8888e-03, 2.8451e-03, 1.0427e-03, 2.9942e-03])),
#                ['asparagus',
#                 'bagels',
#                 'broccoli',
#                 'cake',
#                 'carrots',
#                 'casserole',
#                 'cauliflower',
#                 'chicken_breast',
#                 'cookie',
#                 'croissant',
#                 'dorado',
#                 'eggplant',
#                 'kebab',
#                 'muffin',
#                 'mushrooms',
#                 'nuts',
#                 'pepper',
#                 'pizza',
#                 'pork',
#                 'potatoes',
#                 'rabbit',
#                 'ratatouille',
#                 'ribs',
#                 'salmon',
#                 'steak',
#                 'tilapia',
#                 'tuna_steak',
#                 'whole_chicken']]),
#              ('frame100.jpg',
#               ['nyc_raw_food.pkl',
#                (Category kebab,
#                 tensor(12),
#                 tensor([3.0481e-04, 2.0815e-03, 2.0872e-03, 1.8345e-03, 7.5118e-03, 2.7023e-03,
#                         7.4580e-02, 1.7754e-03, 1.1147e-03, 2.0550e-02, 1.6727e-03, 2.4178e-03,
#                         7.2035e-01, 1.3450e-02, 7.8299e-04, 4.0438e-04, 4.4851e-02, 4.1129e-03,
#                         2.3343e-02, 1.2204e-04, 4.2804e-02, 4.9083e-03, 4.3160e-03, 1.4117e-02,
#                         1.8452e-03, 2.3469e-03, 9.1829e-04, 2.6968e-03])),
#                ['asparagus',
#                 'bagels',
#                 'broccoli',
#                 'cake',
#                 'carrots',
#                 'casserole',
#                 'cauliflower',
#                 'chicken_breast',
#                 'cookie',
#                 'croissant',
#                 'dorado',
#                 'eggplant',
#                 'kebab',
#                 'muffin',
#                 'mushrooms',
#                 'nuts',
#                 'pepper',
#                 'pizza',
#                 'pork',
#                 'potatoes',
#                 'rabbit',
#                 'ratatouille',
#                 'ribs',
#                 'salmon',
#                 'steak',
#                 'tilapia',
#                 'tuna_steak',
#                 'whole_chicken']]),
#              ('frame101.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.8273, 0.0010, 0.1717])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame102.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.9089, 0.0009, 0.0901])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame103.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked,
#                 tensor(0),
#                 tensor([9.1642e-01, 8.5843e-04, 8.2726e-02])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame104.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.8535, 0.0011, 0.1454])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame105.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked,
#                 tensor(0),
#                 tensor([9.2831e-01, 9.0342e-04, 7.0788e-02])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame106.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.9355, 0.0010, 0.0635])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame107.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.9521, 0.0012, 0.0468])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame108.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.9155, 0.0013, 0.0832])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame109.jpg',
#               ['nyc_raw_food.pkl',
#                (Category kebab,
#                 tensor(12),
#                 tensor([1.5724e-04, 1.4997e-03, 1.3930e-03, 1.3991e-03, 2.8603e-03, 1.4909e-03,
#                         3.6894e-02, 1.3378e-03, 7.5118e-04, 8.6202e-03, 1.0805e-03, 1.4657e-03,
#                         8.5735e-01, 1.0466e-02, 2.4383e-04, 2.0435e-04, 2.0322e-02, 4.4876e-03,
#                         9.9810e-03, 5.1685e-05, 1.8551e-02, 1.8987e-03, 4.3633e-03, 8.1569e-03,
#                         1.2965e-03, 1.3770e-03, 5.9698e-04, 1.7006e-03])),
#                ['asparagus',
#                 'bagels',
#                 'broccoli',
#                 'cake',
#                 'carrots',
#                 'casserole',
#                 'cauliflower',
#                 'chicken_breast',
#                 'cookie',
#                 'croissant',
#                 'dorado',
#                 'eggplant',
#                 'kebab',
#                 'muffin',
#                 'mushrooms',
#                 'nuts',
#                 'pepper',
#                 'pizza',
#                 'pork',
#                 'potatoes',
#                 'rabbit',
#                 'ratatouille',
#                 'ribs',
#                 'salmon',
#                 'steak',
#                 'tilapia',
#                 'tuna_steak',
#                 'whole_chicken']]),
#              ('frame110.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.8600, 0.0014, 0.1386])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame111.jpg',
#               ['nyc_raw_food.pkl',
#                (Category kebab,
#                 tensor(12),
#                 tensor([8.0143e-05, 9.5565e-04, 6.2097e-04, 5.9050e-04, 1.4214e-03, 9.9367e-04,
#                         1.8921e-02, 9.2846e-04, 4.7534e-04, 5.5508e-03, 6.7460e-04, 9.7884e-04,
#                         9.2057e-01, 5.3403e-03, 1.4094e-04, 1.1220e-04, 9.3957e-03, 2.9895e-03,
#                         4.9106e-03, 3.3028e-05, 1.3321e-02, 1.3127e-03, 2.8128e-03, 3.9569e-03,
#                         6.8091e-04, 8.7463e-04, 3.2030e-04, 1.0379e-03])),
#                ['asparagus',
#                 'bagels',
#                 'broccoli',
#                 'cake',
#                 'carrots',
#                 'casserole',
#                 'cauliflower',
#                 'chicken_breast',
#                 'cookie',
#                 'croissant',
#                 'dorado',
#                 'eggplant',
#                 'kebab',
#                 'muffin',
#                 'mushrooms',
#                 'nuts',
#                 'pepper',
#                 'pizza',
#                 'pork',
#                 'potatoes',
#                 'rabbit',
#                 'ratatouille',
#                 'ribs',
#                 'salmon',
#                 'steak',
#                 'tilapia',
#                 'tuna_steak',
#                 'whole_chicken']]),
#              ('frame112.jpg',
#               ['nyc_raw_food.pkl',
#                (Category kebab,
#                 tensor(12),
#                 tensor([7.4154e-05, 6.7773e-04, 5.9946e-04, 4.2254e-04, 1.2817e-03, 8.2228e-04,
#                         1.4146e-02, 6.9555e-04, 3.6580e-04, 4.1566e-03, 6.8363e-04, 1.0352e-03,
#                         9.3712e-01, 3.8589e-03, 1.2464e-04, 1.0316e-04, 8.1306e-03, 2.1499e-03,
#                         2.8775e-03, 2.5055e-05, 1.1113e-02, 1.0442e-03, 2.5276e-03, 3.4816e-03,
#                         5.3733e-04, 8.0068e-04, 2.6185e-04, 8.8677e-04])),
#                ['asparagus',
#                 'bagels',
#                 'broccoli',
#                 'cake',
#                 'carrots',
#                 'casserole',
#                 'cauliflower',
#                 'chicken_breast',
#                 'cookie',
#                 'croissant',
#                 'dorado',
#                 'eggplant',
#                 'kebab',
#                 'muffin',
#                 'mushrooms',
#                 'nuts',
#                 'pepper',
#                 'pizza',
#                 'pork',
#                 'potatoes',
#                 'rabbit',
#                 'ratatouille',
#                 'ribs',
#                 'salmon',
#                 'steak',
#                 'tilapia',
#                 'tuna_steak',
#                 'whole_chicken']]),
#              ('frame113.jpg',
#               ['nyc_raw_food.pkl',
#                (Category kebab,
#                 tensor(12),
#                 tensor([1.0310e-04, 8.0071e-04, 8.1499e-04, 4.6928e-04, 1.9512e-03, 1.1196e-03,
#                         1.6994e-02, 1.0347e-03, 4.6661e-04, 8.5243e-03, 8.1647e-04, 9.0985e-04,
#                         9.1613e-01, 4.9769e-03, 1.6196e-04, 1.1661e-04, 1.1568e-02, 2.1910e-03,
#                         4.0969e-03, 3.4575e-05, 1.5007e-02, 1.0721e-03, 3.1457e-03, 4.4330e-03,
#                         6.4955e-04, 9.4927e-04, 2.7991e-04, 1.1799e-03])),
#                ['asparagus',
#                 'bagels',
#                 'broccoli',
#                 'cake',
#                 'carrots',
#                 'casserole',
#                 'cauliflower',
#                 'chicken_breast',
#                 'cookie',
#                 'croissant',
#                 'dorado',
#                 'eggplant',
#                 'kebab',
#                 'muffin',
#                 'mushrooms',
#                 'nuts',
#                 'pepper',
#                 'pizza',
#                 'pork',
#                 'potatoes',
#                 'rabbit',
#                 'ratatouille',
#                 'ribs',
#                 'salmon',
#                 'steak',
#                 'tilapia',
#                 'tuna_steak',
#                 'whole_chicken']]),
#              ('frame114.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.9105, 0.0013, 0.0882])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame115.jpg',
#               ['nyc_raw_food.pkl',
#                (Category kebab,
#                 tensor(12),
#                 tensor([1.3585e-04, 1.0013e-03, 9.1747e-04, 6.8251e-04, 1.9028e-03, 1.2650e-03,
#                         1.6469e-02, 1.3114e-03, 5.4961e-04, 9.1496e-03, 9.3472e-04, 1.2763e-03,
#                         8.9876e-01, 7.2496e-03, 1.9605e-04, 1.5750e-04, 1.6518e-02, 3.4480e-03,
#                         4.8216e-03, 5.1403e-05, 2.0660e-02, 1.5044e-03, 3.3505e-03, 4.4933e-03,
#                         6.8349e-04, 9.8374e-04, 2.9151e-04, 1.2321e-03])),
#                ['asparagus',
#                 'bagels',
#                 'broccoli',
#                 'cake',
#                 'carrots',
#                 'casserole',
#                 'cauliflower',
#                 'chicken_breast',
#                 'cookie',
#                 'croissant',
#                 'dorado',
#                 'eggplant',
#                 'kebab',
#                 'muffin',
#                 'mushrooms',
#                 'nuts',
#                 'pepper',
#                 'pizza',
#                 'pork',
#                 'potatoes',
#                 'rabbit',
#                 'ratatouille',
#                 'ribs',
#                 'salmon',
#                 'steak',
#                 'tilapia',
#                 'tuna_steak',
#                 'whole_chicken']]),
#              ('frame116.jpg',
#               ['nyc_raw_food.pkl',
#                (Category kebab,
#                 tensor(12),
#                 tensor([7.7156e-05, 5.1837e-04, 4.5265e-04, 3.3556e-04, 1.3729e-03, 6.7455e-04,
#                         5.9668e-03, 7.6357e-04, 3.7918e-04, 7.0133e-03, 6.9667e-04, 6.4989e-04,
#                         9.5084e-01, 3.2023e-03, 1.1272e-04, 8.1874e-05, 6.1414e-03, 1.7764e-03,
#                         1.5417e-03, 3.2743e-05, 8.6894e-03, 8.3728e-04, 2.1751e-03, 3.5218e-03,
#                         4.5771e-04, 6.9752e-04, 1.9481e-04, 7.9598e-04])),
#                ['asparagus',
#                 'bagels',
#                 'broccoli',
#                 'cake',
#                 'carrots',
#                 'casserole',
#                 'cauliflower',
#                 'chicken_breast',
#                 'cookie',
#                 'croissant',
#                 'dorado',
#                 'eggplant',
#                 'kebab',
#                 'muffin',
#                 'mushrooms',
#                 'nuts',
#                 'pepper',
#                 'pizza',
#                 'pork',
#                 'potatoes',
#                 'rabbit',
#                 'ratatouille',
#                 'ribs',
#                 'salmon',
#                 'steak',
#                 'tilapia',
#                 'tuna_steak',
#                 'whole_chicken']]),
#              ('frame117.jpg',
#               ['nyc_raw_food.pkl',
#                (Category kebab,
#                 tensor(12),
#                 tensor([8.9542e-05, 5.3640e-04, 5.2375e-04, 4.0588e-04, 1.2270e-03, 7.5896e-04,
#                         5.1942e-03, 8.6640e-04, 3.9205e-04, 8.9653e-03, 8.2515e-04, 6.6243e-04,
#                         9.4860e-01, 3.0307e-03, 1.3752e-04, 7.7268e-05, 5.9982e-03, 1.8913e-03,
#                         2.0227e-03, 4.4710e-05, 9.5479e-03, 1.1429e-03, 2.0327e-03, 2.8890e-03,
#                         4.7603e-04, 6.7876e-04, 2.0110e-04, 7.8199e-04])),
#                ['asparagus',
#                 'bagels',
#                 'broccoli',
#                 'cake',
#                 'carrots',
#                 'casserole',
#                 'cauliflower',
#                 'chicken_breast',
#                 'cookie',
#                 'croissant',
#                 'dorado',
#                 'eggplant',
#                 'kebab',
#                 'muffin',
#                 'mushrooms',
#                 'nuts',
#                 'pepper',
#                 'pizza',
#                 'pork',
#                 'potatoes',
#                 'rabbit',
#                 'ratatouille',
#                 'ribs',
#                 'salmon',
#                 'steak',
#                 'tilapia',
#                 'tuna_steak',
#                 'whole_chicken']]),
#              ('frame118.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked, tensor(0), tensor([0.9498, 0.0010, 0.0492])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame119.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked,
#                 tensor(0),
#                 tensor([9.6519e-01, 8.3505e-04, 3.3977e-02])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame120.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked,
#                 tensor(0),
#                 tensor([9.8848e-01, 3.9871e-04, 1.1116e-02])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('frame121.jpg',
#               ['rn34_base_jeff.pkl',
#                (Category cooked,
#                 tensor(0),
#                 tensor([9.8533e-01, 4.7607e-04, 1.4198e-02])),
#                ['cooked', 'overcooked', 'raw']]),
#              ('fr